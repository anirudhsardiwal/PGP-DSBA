# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Merge and Basics

# %%
df_train_1 = pd.read_csv('Surveydata_train_(1)_(2).csv')
df_train_2 = pd.read_csv('Traveldata_train_(1)_(3).csv')

# %%
df_train = pd.merge(df_train_1, df_train_2, on='ID')

# %%
df_train.head()
# Out:
#          ID  Overall_Experience      Seat_comfort Seat_Class  \
# 0  98800001                   0  need improvement  Green Car
# 1  98800002                   0              poor   Ordinary
# 2  98800003                   1  need improvement  Green Car
# 3  98800004                   0        acceptable   Ordinary
# 4  98800005                   1        acceptable   Ordinary
#
#   Arrival_time_convenient          Catering Platform_location  \
# 0               excellent         excellent   very convinient
# 1               excellent              poor  need improvement
# 2        need improvement  need improvement  need improvement
# 3        need improvement               NaN  need improvement
# 4              acceptable        acceptable        manageable
#
#   Onboardwifi_service Onboard_entertainment Online_support  ...  \
# 0                good      need improvement     acceptable  ...
# 1                good                  poor           good  ...
# ...

# %%
df_train.shape
# Out:
# (94379, 25)

# %%
df_test_1 = pd.read_csv('Surveydata_test_(2).csv')
df_test_2 = pd.read_csv('Traveldata_test_(2).csv')

# %%
df_test = pd.merge(df_test_1, df_test_2, on='ID')

# %%
df_test.shape
# Out:
# (35602, 24)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       94379 non-null  int64
#  1   Overall_Experience       94379 non-null  int64
#  2   Seat_comfort             94318 non-null  object
#  3   Seat_Class               94379 non-null  object
#  4   Arrival_time_convenient  85449 non-null  object
#  5   Catering                 85638 non-null  object
#  6   Platform_location        94349 non-null  object
#  7   Onboardwifi_service      94349 non-null  object
#  8   Onboard_entertainment    94361 non-null  object
#  9   Online_support           94288 non-null  object
#  10  Onlinebooking_Ease       94306 non-null  object
#  11  Onboard_service          86778 non-null  object
#  12  Leg_room                 94289 non-null  object
#  13  Baggage_handling         94237 non-null  object
# ...

# %%
del df_train_1, df_train_2

# %%
del df_test_1, df_test_2

# %%
df_train.isnull().sum()
# Out:
# ID                            0
# Overall_Experience            0
# Seat_comfort                 61
# Seat_Class                    0
# Arrival_time_convenient    8930
# Catering                   8741
# Platform_location            30
# Onboardwifi_service          30
# Onboard_entertainment        18
# Online_support               91
# Onlinebooking_Ease           73
# Onboard_service            7601
# Leg_room                     90
# Baggage_handling            142
# Checkin_service              77
# Cleanliness                   6
# Online_boarding               6
# Gender                       77
# CustomerType               8951
# Age                          33
# TypeTravel                 9226
# Travel_Class                  0
# Travel_Distance               0
# DepartureDelay_in_Mins       57
# ArrivalDelay_in_Mins        357
# dtype: int64

# %%
cols = df_train.columns
for column in cols[1:]:
    print(df_train[column].value_counts(dropna=False))
    print('\n')
# Out:
# Overall_Experience
# 1    51593
# 0    42786
# Name: count, dtype: int64
#
#
# Seat_comfort
# acceptable          21158
# need improvement    20946
# good                20595
# poor                15185
# excellent           12971
# extremely poor       3463
# NaN                    61
# Name: count, dtype: int64
#
#
# Seat_Class
# Green Car    47435
# Ordinary     46944
# Name: count, dtype: int64
#
#
# Arrival_time_convenient
# good                19574
# excellent           17684
# acceptable          15177
# need improvement    14990
# poor                13692
# NaN                  8930
# extremely poor       4332
# Name: count, dtype: int64
#
#
# Catering
# acceptable          18468
# need improvement    17978
# good                17969
# poor                13858
# excellent           13455
# NaN                  8741
# extremely poor       3910
# Name: count, dtype: int64
#
#
# Platform_location
# manageable           24173
# Convinient           21912
# ...

# %% [markdown]
# ## Imputing Values

# %%
cols = df_train.columns
for column in cols[1:]:
    if df_train[column].dtype == 'string':
        df_train[column] = df_train[column].astype('object')

# %%
df_train_a = df_train
df_test_a = df_test

# %%
cols = df_train.columns
for column in cols[1:]:
    if df_train[column].dtype == 'object':
        mode = df_train[column].mode()[0]
        df_train[column] = df_train[column].fillna(mode)

# %%
cols = df_test.columns
for column in cols[1:]:
    if df_test[column].dtype == 'object':
        mode = df_test[column].mode()[0]
        df_test[column] = df_test[column].fillna(mode)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35602 entries, 0 to 35601
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       35602 non-null  int64
#  1   Seat_comfort             35602 non-null  object
#  2   Seat_Class               35602 non-null  object
#  3   Arrival_time_convenient  35602 non-null  object
#  4   Catering                 35602 non-null  object
#  5   Platform_location        35602 non-null  object
#  6   Onboardwifi_service      35602 non-null  object
#  7   Onboard_entertainment    35602 non-null  object
#  8   Online_support           35602 non-null  object
#  9   Onlinebooking_Ease       35602 non-null  object
#  10  Onboard_service          35602 non-null  object
#  11  Leg_room                 35602 non-null  object
#  12  Baggage_handling         35602 non-null  object
#  13  Checkin_service          35602 non-null  object
# ...

# %%
cols = df_train.columns
for column in cols[1:]:
    print(df_train[column].value_counts(dropna=False))
    print('\n')
# Out:
# Overall_Experience
# 1    51593
# 0    42786
# Name: count, dtype: int64
#
#
# Seat_comfort
# acceptable          21219
# need improvement    20946
# good                20595
# poor                15185
# excellent           12971
# extremely poor       3463
# Name: count, dtype: int64
#
#
# Seat_Class
# Green Car    47435
# Ordinary     46944
# Name: count, dtype: int64
#
#
# Arrival_time_convenient
# good                28504
# excellent           17684
# acceptable          15177
# need improvement    14990
# poor                13692
# extremely poor       4332
# Name: count, dtype: int64
#
#
# Catering
# acceptable          27209
# need improvement    17978
# good                17969
# poor                13858
# excellent           13455
# extremely poor       3910
# Name: count, dtype: int64
#
#
# Platform_location
# manageable           24203
# Convinient           21912
# need improvement     17832
# Inconvinient         16449
# very convinient      13981
# ...

# %%
cols = df_test.columns
for column in cols[1:]:
    print(df_test[column].value_counts(dropna=False))
    print('\n')
# Out:
# Seat_comfort
# acceptable          8025
# need improvement    7831
# good                7808
# poor                5755
# excellent           4854
# extremely poor      1329
# Name: count, dtype: int64
#
#
# Seat_Class
# Ordinary     17860
# Green Car    17742
# Name: count, dtype: int64
#
#
# Arrival_time_convenient
# good                10686
# excellent            6589
# acceptable           5844
# need improvement     5684
# poor                 5131
# extremely poor       1668
# Name: count, dtype: int64
#
#
# Catering
# acceptable          10490
# need improvement     6701
# good                 6701
# poor                 5178
# excellent            5025
# extremely poor       1507
# Name: count, dtype: int64
#
#
# Platform_location
# manageable          9376
# Convinient          8178
# need improvement    6703
# Inconvinient        6134
# very convinient     5211
# Name: count, dtype: int64
#
#
# Onboardwifi_service
# good                8755
# excellent           7875
# ...

# %%
df_test.isnull().sum()
# Out:
# ID                           0
# Seat_comfort                 0
# Seat_Class                   0
# Arrival_time_convenient      0
# Catering                     0
# Platform_location            0
# Onboardwifi_service          0
# Onboard_entertainment        0
# Online_support               0
# Onlinebooking_Ease           0
# Onboard_service              0
# Leg_room                     0
# Baggage_handling             0
# Checkin_service              0
# Cleanliness                  0
# Online_boarding              0
# Gender                       0
# CustomerType                 0
# Age                         11
# TypeTravel                   0
# Travel_Class                 0
# Travel_Distance              0
# DepartureDelay_in_Mins      29
# ArrivalDelay_in_Mins       123
# dtype: int64

# %%
cols = df_train.select_dtypes(include=['int64','float64']).columns
for column in cols[1:]:
    median = df_train[column].median()
    df_train[column] = df_train[column].fillna(median)

# %%
cols = df_test.select_dtypes(include=['int64', 'float64']).columns
for column in cols[1:]:
    median = df_test[column].median()
    df_test[column] = df_test[column].fillna(median)

# %%
df_test.isnull().sum()
# Out:
# ID                         0
# Seat_comfort               0
# Seat_Class                 0
# Arrival_time_convenient    0
# Catering                   0
# Platform_location          0
# Onboardwifi_service        0
# Onboard_entertainment      0
# Online_support             0
# Onlinebooking_Ease         0
# Onboard_service            0
# Leg_room                   0
# Baggage_handling           0
# Checkin_service            0
# Cleanliness                0
# Online_boarding            0
# Gender                     0
# CustomerType               0
# Age                        0
# TypeTravel                 0
# Travel_Class               0
# Travel_Distance            0
# DepartureDelay_in_Mins     0
# ArrivalDelay_in_Mins       0
# dtype: int64

# %% [markdown]
# ## Encoding

# %% [markdown]
# ### Encoding Ordinal Variables

# %%
df_train_b = df_train
df_test_b = df_test

# %%
pd.set_option('future.no_silent_downcasting', True)

# %%
df_train = df_train.replace({'extremely poor':1, 'poor':2, 'need improvement':3, 
                             'acceptable':4, 'good':5, 'excellent':6})

# %%
df_test = df_test.replace({'extremely poor':1, 'poor':2, 'need improvement':3, 
                             'acceptable':4, 'good':5, 'excellent':6})

# %%
df_train = df_train.replace({'very inconvinient':1, 'Inconvinient':2, 'need improvement':3, 
                             'manageable':4, 'Convinient':5, 'very convinient':6})

# %%
df_test = df_test.replace({'very inconvinient':1, 'Inconvinient':2, 'need improvement':3, 
                             'manageable':4, 'Convinient':5, 'very convinient':6})

# %%
df_train_c = df_train
df_test_c = df_test

# %%
df_test.head()
# Out:
#          ID Seat_comfort Seat_Class Arrival_time_convenient Catering  \
# 0  99900001            4  Green Car                       4        4
# 1  99900002            1   Ordinary                       5        2
# 2  99900003            6   Ordinary                       6        6
# 3  99900004            4  Green Car                       6        4
# 4  99900005            6   Ordinary                       1        6
#
#   Platform_location Onboardwifi_service Onboard_entertainment Online_support  \
# 0                 4                   3                     6              5
# 1                 4                   4                     2              4
# 2                 6                   6                     6              6
# 3                 6                   2                     4              6
# 4                 3                   6                     6              6
#
#   Onlinebooking_Ease Onboard_service Leg_room Baggage_handling  \
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35602 entries, 0 to 35601
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       35602 non-null  int64
#  1   Seat_comfort             35602 non-null  object
#  2   Seat_Class               35602 non-null  object
#  3   Arrival_time_convenient  35602 non-null  object
#  4   Catering                 35602 non-null  object
#  5   Platform_location        35602 non-null  object
#  6   Onboardwifi_service      35602 non-null  object
#  7   Onboard_entertainment    35602 non-null  object
#  8   Online_support           35602 non-null  object
#  9   Onlinebooking_Ease       35602 non-null  object
#  10  Onboard_service          35602 non-null  object
#  11  Leg_room                 35602 non-null  object
#  12  Baggage_handling         35602 non-null  object
#  13  Checkin_service          35602 non-null  object
# ...

# %%
exclude_columns = ['Seat_Class', 'Gender', 'CustomerType', 'TypeTravel', 'Travel_Class']

all_columns = df_train.columns

for column in all_columns:
    if column not in exclude_columns:
        df_train[column] = pd.to_numeric(df_train[column], errors='coerce')

# %%
exclude_columns = ['Seat_Class', 'Gender', 'CustomerType', 'TypeTravel', 'Travel_Class']

all_columns = df_test.columns

for column in all_columns:
    if column not in exclude_columns:
        df_test[column] = pd.to_numeric(df_test[column], errors='coerce')

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35602 entries, 0 to 35601
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       35602 non-null  int64
#  1   Seat_comfort             35602 non-null  int64
#  2   Seat_Class               35602 non-null  object
#  3   Arrival_time_convenient  35602 non-null  int64
#  4   Catering                 35602 non-null  int64
#  5   Platform_location        35602 non-null  int64
#  6   Onboardwifi_service      35602 non-null  int64
#  7   Onboard_entertainment    35602 non-null  int64
#  8   Online_support           35602 non-null  int64
#  9   Onlinebooking_Ease       35602 non-null  int64
#  10  Onboard_service          35602 non-null  int64
#  11  Leg_room                 35602 non-null  int64
#  12  Baggage_handling         35602 non-null  int64
#  13  Checkin_service          35602 non-null  int64
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              94379 non-null  int64
#  1   Overall_Experience              94379 non-null  int64
#  2   Seat_comfort                    94379 non-null  int64
#  3   Arrival_time_convenient         94379 non-null  int64
#  4   Catering                        94379 non-null  int64
#  5   Platform_location               94379 non-null  int64
#  6   Onboardwifi_service             94379 non-null  int64
#  7   Onboard_entertainment           94379 non-null  int64
#  8   Online_support                  94379 non-null  int64
#  9   Onlinebooking_Ease              94379 non-null  int64
#  10  Onboard_service                 94379 non-null  int64
#  11  Leg_room                        94379 non-null  int64
# ...

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Encoding Categorical Variables

# %%
df_train = pd.get_dummies(df_train,drop_first = True)

# %%
df_test = pd.get_dummies(df_test,drop_first = True)

# %%
df_train = df_train.replace({False:0, True:1})

# %%
df_test = df_test.replace({False:0, True:1})

# %%
df_train_d = df_train
df_test_d = df_test

# %%
df_train.head()
# Out:
#          ID  Overall_Experience  Seat_comfort  Arrival_time_convenient  \
# 0  98800001                   0             3                        6
# 1  98800002                   0             2                        6
# 2  98800003                   1             3                        3
# 3  98800004                   0             4                        3
# 4  98800005                   1             4                        4
#
#    Catering  Onboardwifi_service  Onboard_entertainment  Online_support  \
# 0         6                    5                      3               4
# 1         2                    5                      2               5
# 2         3                    3                      5               6
# 3         4                    4                      3               4
# 4         4                    3                      5               6
#
#    Onlinebooking_Ease  Onboard_service  Leg_room  Baggage_handling  \
# ...

# %%
df_test.head()
# Out:
#          ID  Seat_comfort  Arrival_time_convenient  Catering  \
# 0  99900001             4                        4         4
# 1  99900002             1                        5         2
# 2  99900003             6                        6         6
# 3  99900004             4                        6         4
# 4  99900005             6                        1         6
#
#    Platform_location  Onboardwifi_service  Onboard_entertainment  \
# 0                  4                    3                      6
# 1                  4                    4                      2
# 2                  6                    6                      6
# 3                  6                    2                      4
# 4                  3                    6                      6
#
#    Online_support  Onlinebooking_Ease  Onboard_service  Leg_room  \
# 0               5                   6                6         6
# 1               4                   4                6         4
# ...

# %%
df_test.shape
# Out:
# (35602, 24)

# %%
df_test_temp = pd.merge(df_test_1, df_test_2, on='ID')

# %%
test_file_ids = df_test_temp['ID']

# %%
df_train.drop('ID',axis = 1,inplace = True)

# %%
df_test.drop('ID',axis = 1,inplace = True)

# %%
test_file_ids
# Out:
# 0        99900001
# 1        99900002
# 2        99900003
# 3        99900004
# 4        99900005
#            ...
# 35597    99935598
# 35598    99935599
# 35599    99935600
# 35600    99935601
# 35601    99935602
# Name: ID, Length: 35602, dtype: int64

# %%
cols = df_train.columns

# %%
df_train.to_csv('df_train_encoded.csv', index=False)
df_test.to_csv('df_test_encoded.csv', index=False)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X = pd.read_csv('df_train_encoded.csv')

# %%
df_test = pd.read_csv('df_test_encoded.csv')

# %%
y = X['Overall_Experience']
X = X.drop('Overall_Experience', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
RF_model = RandomForestClassifier(n_estimators=100, random_state=1)
RF_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_auc_score, roc_curve

# %%
y_train_predict = RF_model.predict(X_train)
model_score = RF_model.score(X_train, y_train)
print(f'Model Score for Random Forest (Train): {round(model_score,2)}\n')
print('Confusion Matrix:')
print(metrics.confusion_matrix(y_train, y_train_predict))
print(metrics.classification_report(y_train, y_train_predict))
# Out:
# Model Score for Random Forest (Train): 1.0
#
# Confusion Matrix:
# [[29999     0]
#  [    0 36066]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     29999
#            1       1.00      1.00      1.00     36066
#
#     accuracy                           1.00     66065
#    macro avg       1.00      1.00      1.00     66065
# weighted avg       1.00      1.00      1.00     66065

# %%
y_test_predict = RF_model.predict(X_test)
model_score = RF_model.score(X_test, y_test)
print(f'Model Score for Random Forest (Test): {round(model_score,2)}\n')
print('Confusion Matrix:')
print(metrics.confusion_matrix(y_test, y_test_predict))
print(metrics.classification_report(y_test, y_test_predict))
# Out:
# Model Score for Random Forest (Test): 0.95
#
# Confusion Matrix:
# [[12188   599]
#  [  840 14687]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94     12787
#            1       0.96      0.95      0.95     15527
#
#     accuracy                           0.95     28314
#    macro avg       0.95      0.95      0.95     28314
# weighted avg       0.95      0.95      0.95     28314

# %%
probs_train = RF_model.predict_proba(X_train)[:, 1]
auc_train = roc_auc_score(y_train, probs_train)
auc_train
# Out:
# 1.0

# %%
probs_test = RF_model.predict_proba(X_test)[:, 1]
auc_test = roc_auc_score(y_test, probs_test)
round(auc_test,3)
# Out:
# 0.991

# %% [markdown]
# ### Predictions 1

# %%
final_predictions = RF_model.predict(df_test)

# %%
submission=pd.DataFrame([test_file_ids,final_predictions]).T

# %%
submission.shape
# Out:
# (35602, 2)

# %%
submission.rename(columns={"Unnamed 0": "Overall_Experience"},inplace=True)
submission.to_csv('submission_rf.csv',index = False)

# %% [markdown]
# ### Tuning

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=RF_model, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# KeyboardInterrupt
